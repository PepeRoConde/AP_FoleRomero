# %% [markdown]
# # Redes de Neuronas con conexiones residuales y entrenados según _transfer learning_
# ## Práctica 3
#
# #### Hugo Fole Avellás y José Romero Conde

# %% [markdown]
# NOTA:
#
# La práctica tiene que por un lado programarse y por otro ejecutarse. Ocurrieron complicaciones que imposibiitaron la ejecución en múltipes ocasiones pero creemos que el código es correcto y esta completo. No hacemos en el ejercicio 3 ahorro de memoria.

# %% [markdown]
#  ### $\huge\text{Ejercicio } 1$
#  ### (_2 puntos_) Define la capa ResidualBlock (ver Figura 2), usando como base la plantilla proporcionada en la Figura 3.
#  - Ten en cuenta que el número de convoluciones depende de los valores de input_channels y out-put_channels.
#  - Esta red no tiene capas de Pooling. La reducción del tamaño se realiza con el parámetro strides
# de las convoluciones, pero se modifica únicamente en 1 (o 2) de las convoluciones del modelo.

# %% [markdown]
# !['arquitectura'](ResidualBlock.png)

# %%
from tensorflow.keras import Model
from tensorflow.keras import layers
from tensorflow.keras import activations

class ResidualBlock(Model):
    def __init__(self, input_channels, output_channels, strides=(1, 1)):
        
        super().__init__()
        
        self.BN1 = layers.BatchNormalization()
        self.Conv1 = layers.Conv2D(filters = output_channels, 
                                   kernel_size = (3, 3),
                                   strides = strides,
                                   padding="same",
                                   use_bias=False)
                                   
        self.BN2 = layers.BatchNormalization()
        self.Conv2 = layers.Conv2D(filters = output_channels, 
                                   kernel_size = (3, 3),
                                   strides = (1, 1),
                                   padding="same",
                                   use_bias=False)
        
        if input_channels != output_channels:
            self.salidaDistinta = True
            self.ConvFuera = layers.Conv2D(filters = output_channels, 
                                   kernel_size = (1, 1),
                                   strides = strides,
                                   use_bias=False)
        else: self.salidaDistinta = False
            
    def call(self, x):
        x = self.BN1(x)
        y = activations.silu(x)
        x = self.Conv1(y)
        x = self.BN2(x)
        x = activations.silu(x)
        x = self.Conv2(x)
        if self.salidaDistinta:
            y = self.ConvFuera(y)
        x = x + y
        return x

# %% [markdown]
#  ### $\huge\text{Ejercicio } 2$
# ### (_2 puntos_) Define la red ResidualNetwork (ver Figura 1). Para comprobar su correcto funcionamiento haz lo siguiente:
#  - Descarga los pesos del modelo preentrenado (los podrás encontrar en el canal de Teams de la asignatura).
#  - Carga los pesos en tu modelo, haciendo uso de la función proporcionada en la Figura 4.
#  - Comprueba que la precisión del modelo en CIFAR-100 es superior al 69 %.

# %% [markdown]
# !['arquitectura'](ResidualNetwork.png)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras import Input

ResidualNetwork = Sequential([
    Input(shape=(32,32,3)),
    layers.Conv2D(filters=16, kernel_size=(3,3),strides=(1,1),padding="same", use_bias=False), 
    # la configuración de la capa convolucional es para asegurarse que no se reduce tamaño
    ResidualBlock(16,64),
    ResidualBlock(64,64),
    ResidualBlock(64,64),
    ResidualBlock(64,128,strides=(2,2)),
    ResidualBlock(128,128),
    ResidualBlock(128,128),
    ResidualBlock(128,256,strides=(2,2)),
    ResidualBlock(256,256),
    ResidualBlock(256,256),
    layers.BatchNormalization(),
    layers.Activation(activations.silu),
    layers.GlobalAveragePooling2D(),
    layers.Dense(100,activation='softmax')
    
])

# %%
import pickle

def load_weights(model, weight_file):
    with open(weight_file, 'rb') as f:
        weights = pickle.load(f)

    all_vars = model.trainable_weights + model.non_trainable_weights
    weight_list = [(x, weights[x]) for x in sorted(weights.keys())]
    weights = {}
    for i, var in enumerate(all_vars):
        aux = var.path.split('/')[-2:]
        classname = '_'.join(aux[0].split('_')[:-1])
        name = aux[1]
        assigned = False
        for j, (key, value) in enumerate(weight_list):
            if classname in key and name in key:
                try:
                    all_vars[i].assign(value)
                    print(':) ',end='')
                except:
                    continue
                print('assinging', key, 'to', var.path)
                del weight_list[j]
                assigned = True
                break
        if not assigned:
            #raise Exception(var.path + ' cannot be loaded')
            print(var.path + ' cannot be loaded')

# %%
load_weights(ResidualNetwork, "p2_model_weights.pkl")
# Out:
# :) assinging conv2d_52/kernel to sequential/conv2d/kernel
# :) assinging batch_normalization_38/gamma to sequential/residual_block/batch_normalization/gamma
# :) assinging batch_normalization_38/beta to sequential/residual_block/batch_normalization/beta
# :) assinging conv2d_54/kernel to sequential/residual_block/conv2d_1/kernel
# :) assinging batch_normalization_39/gamma to sequential/residual_block/batch_normalization_1/gamma
# :) assinging batch_normalization_39/beta to sequential/residual_block/batch_normalization_1/beta
# :) assinging conv2d_55/kernel to sequential/residual_block/conv2d_2/kernel
# :) assinging conv2d_53/kernel to sequential/residual_block/conv2d_3/kernel
# :) assinging batch_normalization_40/gamma to sequential/residual_block_1/batch_normalization_2/gamma
# :) assinging batch_normalization_40/beta to sequential/residual_block_1/batch_normalization_2/beta
# :) assinging conv2d_56/kernel to sequential/residual_block_1/conv2d_4/kernel
# :) assinging batch_normalization_41/gamma to sequential/residual_block_1/batch_normalization_3/gamma
# :) assinging batch_normalization_41/beta to sequential/residual_block_1/batch_normalization_3/beta
# :) assinging conv2d_57/kernel to sequential/residual_block_1/conv2d_5/kernel
# :) assinging batch_normalization_42/gamma to sequential/residual_block_2/batch_normalization_4/gamma
# :) assinging batch_normalization_42/beta to sequential/residual_block_2/batch_normalization_4/beta
# :) assinging conv2d_58/kernel to sequential/residual_block_2/conv2d_6/kernel
# :) assinging batch_normalization_43/gamma to sequential/residual_block_2/batch_normalization_5/gamma
# :) assinging batch_normalization_43/beta to sequential/residual_block_2/batch_normalization_5/beta
# :) assinging conv2d_59/kernel to sequential/residual_block_2/conv2d_7/kernel
# :) assinging batch_normalization_44/gamma to sequential/residual_block_3/batch_normalization_6/gamma
# :) assinging batch_normalization_44/beta to sequential/residual_block_3/batch_normalization_6/beta
# :) assinging conv2d_61/kernel to sequential/residual_block_3/conv2d_8/kernel
# :) assinging batch_normalization_45/gamma to sequential/residual_block_3/batch_normalization_7/gamma
# :) assinging batch_normalization_45/beta to sequential/residual_block_3/batch_normalization_7/beta
# :) assinging conv2d_62/kernel to sequential/residual_block_3/conv2d_9/kernel
# :) assinging conv2d_60/kernel to sequential/residual_block_3/conv2d_10/kernel
# :) assinging batch_normalization_46/gamma to sequential/residual_block_4/batch_normalization_8/gamma
# :) assinging batch_normalization_46/beta to sequential/residual_block_4/batch_normalization_8/beta
# :) assinging conv2d_63/kernel to sequential/residual_block_4/conv2d_11/kernel
# :) assinging batch_normalization_47/gamma to sequential/residual_block_4/batch_normalization_9/gamma
# :) assinging batch_normalization_47/beta to sequential/residual_block_4/batch_normalization_9/beta
# :) assinging conv2d_64/kernel to sequential/residual_block_4/conv2d_12/kernel
# :) assinging batch_normalization_48/gamma to sequential/residual_block_5/batch_normalization_10/gamma
# :) assinging batch_normalization_48/beta to sequential/residual_block_5/batch_normalization_10/beta
# :) assinging conv2d_65/kernel to sequential/residual_block_5/conv2d_13/kernel
# :) assinging batch_normalization_49/gamma to sequential/residual_block_5/batch_normalization_11/gamma
# :) assinging batch_normalization_49/beta to sequential/residual_block_5/batch_normalization_11/beta
# :) assinging conv2d_66/kernel to sequential/residual_block_5/conv2d_14/kernel
# :) assinging batch_normalization_50/gamma to sequential/residual_block_6/batch_normalization_12/gamma
# :) assinging batch_normalization_50/beta to sequential/residual_block_6/batch_normalization_12/beta
# :) assinging conv2d_68/kernel to sequential/residual_block_6/conv2d_15/kernel
# :) assinging batch_normalization_51/gamma to sequential/residual_block_6/batch_normalization_13/gamma
# :) assinging batch_normalization_51/beta to sequential/residual_block_6/batch_normalization_13/beta
# :) assinging conv2d_69/kernel to sequential/residual_block_6/conv2d_16/kernel
# :) assinging conv2d_67/kernel to sequential/residual_block_6/conv2d_17/kernel
# :) assinging batch_normalization_52/gamma to sequential/residual_block_7/batch_normalization_14/gamma
# :) assinging batch_normalization_52/beta to sequential/residual_block_7/batch_normalization_14/beta
# :) assinging conv2d_70/kernel to sequential/residual_block_7/conv2d_18/kernel
# :) assinging batch_normalization_53/gamma to sequential/residual_block_7/batch_normalization_15/gamma
# :) assinging batch_normalization_53/beta to sequential/residual_block_7/batch_normalization_15/beta
# :) assinging conv2d_71/kernel to sequential/residual_block_7/conv2d_19/kernel
# :) assinging batch_normalization_54/gamma to sequential/residual_block_8/batch_normalization_16/gamma
# :) assinging batch_normalization_54/beta to sequential/residual_block_8/batch_normalization_16/beta
# :) assinging conv2d_72/kernel to sequential/residual_block_8/conv2d_20/kernel
# :) assinging batch_normalization_55/gamma to sequential/residual_block_8/batch_normalization_17/gamma
# :) assinging batch_normalization_55/beta to sequential/residual_block_8/batch_normalization_17/beta
# :) assinging conv2d_73/kernel to sequential/residual_block_8/conv2d_21/kernel
# :) assinging batch_normalization_56/gamma to sequential/batch_normalization_18/gamma
# :) assinging batch_normalization_56/beta to sequential/batch_normalization_18/beta
# :) assinging dense_2/kernel to sequential/dense/kernel
# :) assinging dense_2/bias to sequential/dense/bias
# :) assinging batch_normalization_38/moving_mean to sequential/residual_block/batch_normalization/moving_mean
# :) assinging batch_normalization_38/moving_variance to sequential/residual_block/batch_normalization/moving_variance
# :) assinging batch_normalization_39/moving_mean to sequential/residual_block/batch_normalization_1/moving_mean
# :) assinging batch_normalization_39/moving_variance to sequential/residual_block/batch_normalization_1/moving_variance
# :) assinging batch_normalization_40/moving_mean to sequential/residual_block_1/batch_normalization_2/moving_mean
# :) assinging batch_normalization_40/moving_variance to sequential/residual_block_1/batch_normalization_2/moving_variance
# :) assinging batch_normalization_41/moving_mean to sequential/residual_block_1/batch_normalization_3/moving_mean
# :) assinging batch_normalization_41/moving_variance to sequential/residual_block_1/batch_normalization_3/moving_variance
# :) assinging batch_normalization_42/moving_mean to sequential/residual_block_2/batch_normalization_4/moving_mean
# :) assinging batch_normalization_42/moving_variance to sequential/residual_block_2/batch_normalization_4/moving_variance
# :) assinging batch_normalization_43/moving_mean to sequential/residual_block_2/batch_normalization_5/moving_mean
# :) assinging batch_normalization_43/moving_variance to sequential/residual_block_2/batch_normalization_5/moving_variance
# :) assinging batch_normalization_44/moving_mean to sequential/residual_block_3/batch_normalization_6/moving_mean
# :) assinging batch_normalization_44/moving_variance to sequential/residual_block_3/batch_normalization_6/moving_variance
# :) assinging batch_normalization_45/moving_mean to sequential/residual_block_3/batch_normalization_7/moving_mean
# :) assinging batch_normalization_45/moving_variance to sequential/residual_block_3/batch_normalization_7/moving_variance
# :) assinging batch_normalization_46/moving_mean to sequential/residual_block_4/batch_normalization_8/moving_mean
# :) assinging batch_normalization_46/moving_variance to sequential/residual_block_4/batch_normalization_8/moving_variance
# :) assinging batch_normalization_47/moving_mean to sequential/residual_block_4/batch_normalization_9/moving_mean
# :) assinging batch_normalization_47/moving_variance to sequential/residual_block_4/batch_normalization_9/moving_variance
# :) assinging batch_normalization_48/moving_mean to sequential/residual_block_5/batch_normalization_10/moving_mean
# :) assinging batch_normalization_48/moving_variance to sequential/residual_block_5/batch_normalization_10/moving_variance
# :) assinging batch_normalization_49/moving_mean to sequential/residual_block_5/batch_normalization_11/moving_mean
# :) assinging batch_normalization_49/moving_variance to sequential/residual_block_5/batch_normalization_11/moving_variance
# :) assinging batch_normalization_50/moving_mean to sequential/residual_block_6/batch_normalization_12/moving_mean
# :) assinging batch_normalization_50/moving_variance to sequential/residual_block_6/batch_normalization_12/moving_variance
# :) assinging batch_normalization_51/moving_mean to sequential/residual_block_6/batch_normalization_13/moving_mean
# :) assinging batch_normalization_51/moving_variance to sequential/residual_block_6/batch_normalization_13/moving_variance
# :) assinging batch_normalization_52/moving_mean to sequential/residual_block_7/batch_normalization_14/moving_mean
# :) assinging batch_normalization_52/moving_variance to sequential/residual_block_7/batch_normalization_14/moving_variance
# :) assinging batch_normalization_53/moving_mean to sequential/residual_block_7/batch_normalization_15/moving_mean
# :) assinging batch_normalization_53/moving_variance to sequential/residual_block_7/batch_normalization_15/moving_variance
# :) assinging batch_normalization_54/moving_mean to sequential/residual_block_8/batch_normalization_16/moving_mean
# :) assinging batch_normalization_54/moving_variance to sequential/residual_block_8/batch_normalization_16/moving_variance
# :) assinging batch_normalization_55/moving_mean to sequential/residual_block_8/batch_normalization_17/moving_mean
# :) assinging batch_normalization_55/moving_variance to sequential/residual_block_8/batch_normalization_17/moving_variance
# :) assinging batch_normalization_56/moving_mean to sequential/batch_normalization_18/moving_mean
# :) assinging batch_normalization_56/moving_variance to sequential/batch_normalization_18/moving_variance

# %%
## carga y procesado de datos

from tensorflow.keras.datasets import cifar100
import numpy as np

(x_train, Y_train), (x_test, Y_test) = cifar100.load_data()

x_train = (2*x_train.astype(float)-255)/(255)
x_test = (2*x_test.astype(float)-255)/(255)

# como la salida de la red son 100 nodos se sobreentiende 
# que tengo que one-hot-ear Y

y_train = np.zeros(shape=(Y_train.shape[0],max(Y_train)[0]+1))
y_train[np.arange(Y_train.size),Y_train.T] = 1

y_test = np.zeros(shape=(Y_test.shape[0],max(Y_test)[0]+1))
y_test[np.arange(Y_test.size),Y_test.T] = 1

(np.max(x_train),np.min(x_train),np.max(x_test),np.min(x_test))
# Out:
# (1.0, -1.0, 1.0, -1.0)

# %%
# comprobación de que la carga de pesos fue correcta
from random import randint

def compruebaConTest(modelo, numeroEjemplos):
    indices = [randint(0,x_test.shape[0]-1) for _ in range(numeroEjemplos)]
    y_pred = modelo(x_test[indices])
    tasaAcierto = sum([np.argmax(y_pred[i]) == np.argmax(y_test[indice]) for i, indice in enumerate(indices)])/numeroEjemplos
    print(f'    La tasa de acierto es {tasaAcierto}')
    return tasaAcierto

# %%
# descomentar para comprobar
compruebaConTest(ResidualNetwork, 2000);
# Out:
#     La tasa de acierto es 0.7095

# %% [markdown]
#  ### $\huge\text{Ejercicio } 3$
# ### (_4 puntos_) Entrena, mediante la técnica de fine-tuning, sobre el dataset CIFAR-10, manteniendo fijos los pesos de la red preentrenada proporcionada en el canal de Teams de la asignatura. Analiza el resultado en el conjunto de test. Se penalizarán los siguientes puntos:
#  - (_-4 puntos_) No se ha entrenado la red correctamente, y no se proporciona el resultado obtenido en
# el conjunto de test.
#  - (_-1 punto_) No se ha utilizado la red original completa, a excepción de la última capa.
#  - (_-1 punto_) No se optimizado el entrenamiento, reduciendo al máximo el consumo de memoria.
#  - (_-1 punto_) No se ha hecho uso de técnicas de DataAugmentation sobre las imágenes de entrenamiento.
#  - (_-2 puntos_) No se ha entrenado la red sin hacer uso de la función fit, entrenando el modelo con un
# bucle de entrenamiento desde cero.

# %%
# primero que todo, tenemos que cargar los datos

from tensorflow.keras.datasets import cifar10
import numpy as np

(x_train, Y_train), (x_test, Y_test) = cifar10.load_data()

x_train = (2*x_train.astype(float)-255)/(255)
x_test = (2*x_test.astype(float)-255)/(255)

y_train = np.zeros(shape=(Y_train.shape[0],max(Y_train)[0]+1))
y_train[np.arange(Y_train.size),Y_train.T] = 1

y_test = np.zeros(shape=(Y_test.shape[0],max(Y_test)[0]+1))
y_test[np.arange(Y_test.size),Y_test.T] = 1

(np.max(x_train),np.min(x_train),np.max(x_test),np.min(x_test))
# Out:
# (1.0, -1.0, 1.0, -1.0)

# %%
# redefinimos el modelo

from tensorflow.keras import Sequential
from tensorflow.keras import Input
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import RandomRotation
from tensorflow.keras.layers import RandomTranslation
from tensorflow.keras.layers import RandomFlip
from tensorflow.keras.layers import RandomContrast

# extractor de caracteristicas

aumentoDeDatos = Sequential(
    [
        RandomRotation(factor = .3), # rotaciones
        RandomTranslation(height_factor = .2, width_factor = .2), # traslaciones
        RandomFlip(), # giros
        RandomContrast(factor = .2),  # contraste
    ],
)

ResidualNetworkSinClasificador = Sequential([
    Input(shape=(32,32,3)),
    layers.Conv2D(filters=16, kernel_size=(3,3),strides=(1,1),padding="same", use_bias=False), 
    # la configuración de la capa convolucional es para asegurarse que no se reduce tamaño
    ResidualBlock(16,64),
    ResidualBlock(64,64),
    ResidualBlock(64,64),
    ResidualBlock(64,128,strides=(2,2)),
    ResidualBlock(128,128),
    ResidualBlock(128,128),
    ResidualBlock(128,256,strides=(2,2)),
    ResidualBlock(256,256),
    ResidualBlock(256,256),
    layers.BatchNormalization(),
    layers.Activation(activations.silu),
    layers.GlobalAveragePooling2D(),
    # lo unico que cambio es que la ultima capa, ahora no la tiene
    # lo hacemos así porque de esta forma todo es no entrenable
    
])
'''

load_weights(ResidualNetworkSinClasificador, "p2_model_weights.pkl")
x_train = aumentoDeDatos(x_train)
print('datos aumentados!')
#x_train = ResidualNetworkSinClasificador(x_train)
#print('características extraidas!')

'''
ResidualNetworkSinClasificador.trainable = False # que sea no entrenable

Clasificador = Sequential( # definimos el clasificador
    [
        Dropout(rate = .05),
        Dense(20, activation = 'relu'),
        Dropout(rate = .05),
        Dense(10, activation = 'softmax') # Dense con salida el número de clases del dataset
                                             # Softmax activation
    ]
)

# entrada
input = Input(shape = (32,32,3))  # capa de input
input = aumentoDeDatos(input) # le aplicamos el aumento de datos

# salida
outputs = ResidualNetworkSinClasificador(inputs = input)
outputs = Clasificador(inputs = outputs)

# modelo
modeloEjercicio3 = Model(inputs = input, outputs = outputs, name = "ejercicio3")
load_weights(modeloEjercicio3, "p2_model_weights.pkl")
# Out:
# sequential_3/dense_1/kernel cannot be loaded
# sequential_3/dense_1/bias cannot be loaded
# sequential_3/dense_2/kernel cannot be loaded
# sequential_3/dense_2/bias cannot be loaded
# :) assinging conv2d_52/kernel to sequential_2/conv2d_22/kernel
# :) assinging batch_normalization_38/gamma to sequential_2/residual_block_9/batch_normalization_19/gamma
# :) assinging batch_normalization_38/beta to sequential_2/residual_block_9/batch_normalization_19/beta
# :) assinging batch_normalization_38/moving_mean to sequential_2/residual_block_9/batch_normalization_19/moving_mean
# :) assinging batch_normalization_38/moving_variance to sequential_2/residual_block_9/batch_normalization_19/moving_variance
# :) assinging conv2d_54/kernel to sequential_2/residual_block_9/conv2d_23/kernel
# :) assinging batch_normalization_39/gamma to sequential_2/residual_block_9/batch_normalization_20/gamma
# :) assinging batch_normalization_39/beta to sequential_2/residual_block_9/batch_normalization_20/beta
# :) assinging batch_normalization_39/moving_mean to sequential_2/residual_block_9/batch_normalization_20/moving_mean
# :) assinging batch_normalization_39/moving_variance to sequential_2/residual_block_9/batch_normalization_20/moving_variance
# :) assinging conv2d_55/kernel to sequential_2/residual_block_9/conv2d_24/kernel
# :) assinging conv2d_53/kernel to sequential_2/residual_block_9/conv2d_25/kernel
# :) assinging batch_normalization_40/gamma to sequential_2/residual_block_10/batch_normalization_21/gamma
# :) assinging batch_normalization_40/beta to sequential_2/residual_block_10/batch_normalization_21/beta
# :) assinging batch_normalization_40/moving_mean to sequential_2/residual_block_10/batch_normalization_21/moving_mean
# :) assinging batch_normalization_40/moving_variance to sequential_2/residual_block_10/batch_normalization_21/moving_variance
# :) assinging conv2d_56/kernel to sequential_2/residual_block_10/conv2d_26/kernel
# :) assinging batch_normalization_41/gamma to sequential_2/residual_block_10/batch_normalization_22/gamma
# :) assinging batch_normalization_41/beta to sequential_2/residual_block_10/batch_normalization_22/beta
# :) assinging batch_normalization_41/moving_mean to sequential_2/residual_block_10/batch_normalization_22/moving_mean
# :) assinging batch_normalization_41/moving_variance to sequential_2/residual_block_10/batch_normalization_22/moving_variance
# :) assinging conv2d_57/kernel to sequential_2/residual_block_10/conv2d_27/kernel
# :) assinging batch_normalization_42/gamma to sequential_2/residual_block_11/batch_normalization_23/gamma
# :) assinging batch_normalization_42/beta to sequential_2/residual_block_11/batch_normalization_23/beta
# :) assinging batch_normalization_42/moving_mean to sequential_2/residual_block_11/batch_normalization_23/moving_mean
# :) assinging batch_normalization_42/moving_variance to sequential_2/residual_block_11/batch_normalization_23/moving_variance
# :) assinging conv2d_58/kernel to sequential_2/residual_block_11/conv2d_28/kernel
# :) assinging batch_normalization_43/gamma to sequential_2/residual_block_11/batch_normalization_24/gamma
# :) assinging batch_normalization_43/beta to sequential_2/residual_block_11/batch_normalization_24/beta
# :) assinging batch_normalization_43/moving_mean to sequential_2/residual_block_11/batch_normalization_24/moving_mean
# :) assinging batch_normalization_43/moving_variance to sequential_2/residual_block_11/batch_normalization_24/moving_variance
# :) assinging conv2d_59/kernel to sequential_2/residual_block_11/conv2d_29/kernel
# :) assinging batch_normalization_44/gamma to sequential_2/residual_block_12/batch_normalization_25/gamma
# :) assinging batch_normalization_44/beta to sequential_2/residual_block_12/batch_normalization_25/beta
# :) assinging batch_normalization_44/moving_mean to sequential_2/residual_block_12/batch_normalization_25/moving_mean
# :) assinging batch_normalization_44/moving_variance to sequential_2/residual_block_12/batch_normalization_25/moving_variance
# :) assinging conv2d_61/kernel to sequential_2/residual_block_12/conv2d_30/kernel
# :) assinging batch_normalization_45/gamma to sequential_2/residual_block_12/batch_normalization_26/gamma
# :) assinging batch_normalization_45/beta to sequential_2/residual_block_12/batch_normalization_26/beta
# :) assinging batch_normalization_45/moving_mean to sequential_2/residual_block_12/batch_normalization_26/moving_mean
# :) assinging batch_normalization_45/moving_variance to sequential_2/residual_block_12/batch_normalization_26/moving_variance
# :) assinging conv2d_62/kernel to sequential_2/residual_block_12/conv2d_31/kernel
# :) assinging conv2d_60/kernel to sequential_2/residual_block_12/conv2d_32/kernel
# :) assinging batch_normalization_46/gamma to sequential_2/residual_block_13/batch_normalization_27/gamma
# :) assinging batch_normalization_46/beta to sequential_2/residual_block_13/batch_normalization_27/beta
# :) assinging batch_normalization_46/moving_mean to sequential_2/residual_block_13/batch_normalization_27/moving_mean
# :) assinging batch_normalization_46/moving_variance to sequential_2/residual_block_13/batch_normalization_27/moving_variance
# :) assinging conv2d_63/kernel to sequential_2/residual_block_13/conv2d_33/kernel
# :) assinging batch_normalization_47/gamma to sequential_2/residual_block_13/batch_normalization_28/gamma
# :) assinging batch_normalization_47/beta to sequential_2/residual_block_13/batch_normalization_28/beta
# :) assinging batch_normalization_47/moving_mean to sequential_2/residual_block_13/batch_normalization_28/moving_mean
# :) assinging batch_normalization_47/moving_variance to sequential_2/residual_block_13/batch_normalization_28/moving_variance
# :) assinging conv2d_64/kernel to sequential_2/residual_block_13/conv2d_34/kernel
# :) assinging batch_normalization_48/gamma to sequential_2/residual_block_14/batch_normalization_29/gamma
# :) assinging batch_normalization_48/beta to sequential_2/residual_block_14/batch_normalization_29/beta
# :) assinging batch_normalization_48/moving_mean to sequential_2/residual_block_14/batch_normalization_29/moving_mean
# :) assinging batch_normalization_48/moving_variance to sequential_2/residual_block_14/batch_normalization_29/moving_variance
# :) assinging conv2d_65/kernel to sequential_2/residual_block_14/conv2d_35/kernel
# :) assinging batch_normalization_49/gamma to sequential_2/residual_block_14/batch_normalization_30/gamma
# :) assinging batch_normalization_49/beta to sequential_2/residual_block_14/batch_normalization_30/beta
# :) assinging batch_normalization_49/moving_mean to sequential_2/residual_block_14/batch_normalization_30/moving_mean
# :) assinging batch_normalization_49/moving_variance to sequential_2/residual_block_14/batch_normalization_30/moving_variance
# :) assinging conv2d_66/kernel to sequential_2/residual_block_14/conv2d_36/kernel
# :) assinging batch_normalization_50/gamma to sequential_2/residual_block_15/batch_normalization_31/gamma
# :) assinging batch_normalization_50/beta to sequential_2/residual_block_15/batch_normalization_31/beta
# :) assinging batch_normalization_50/moving_mean to sequential_2/residual_block_15/batch_normalization_31/moving_mean
# :) assinging batch_normalization_50/moving_variance to sequential_2/residual_block_15/batch_normalization_31/moving_variance
# :) assinging conv2d_68/kernel to sequential_2/residual_block_15/conv2d_37/kernel
# :) assinging batch_normalization_51/gamma to sequential_2/residual_block_15/batch_normalization_32/gamma
# :) assinging batch_normalization_51/beta to sequential_2/residual_block_15/batch_normalization_32/beta
# :) assinging batch_normalization_51/moving_mean to sequential_2/residual_block_15/batch_normalization_32/moving_mean
# :) assinging batch_normalization_51/moving_variance to sequential_2/residual_block_15/batch_normalization_32/moving_variance
# :) assinging conv2d_69/kernel to sequential_2/residual_block_15/conv2d_38/kernel
# :) assinging conv2d_67/kernel to sequential_2/residual_block_15/conv2d_39/kernel
# :) assinging batch_normalization_52/gamma to sequential_2/residual_block_16/batch_normalization_33/gamma
# :) assinging batch_normalization_52/beta to sequential_2/residual_block_16/batch_normalization_33/beta
# :) assinging batch_normalization_52/moving_mean to sequential_2/residual_block_16/batch_normalization_33/moving_mean
# :) assinging batch_normalization_52/moving_variance to sequential_2/residual_block_16/batch_normalization_33/moving_variance
# :) assinging conv2d_70/kernel to sequential_2/residual_block_16/conv2d_40/kernel
# :) assinging batch_normalization_53/gamma to sequential_2/residual_block_16/batch_normalization_34/gamma
# :) assinging batch_normalization_53/beta to sequential_2/residual_block_16/batch_normalization_34/beta
# :) assinging batch_normalization_53/moving_mean to sequential_2/residual_block_16/batch_normalization_34/moving_mean
# :) assinging batch_normalization_53/moving_variance to sequential_2/residual_block_16/batch_normalization_34/moving_variance
# :) assinging conv2d_71/kernel to sequential_2/residual_block_16/conv2d_41/kernel
# :) assinging batch_normalization_54/gamma to sequential_2/residual_block_17/batch_normalization_35/gamma
# :) assinging batch_normalization_54/beta to sequential_2/residual_block_17/batch_normalization_35/beta
# :) assinging batch_normalization_54/moving_mean to sequential_2/residual_block_17/batch_normalization_35/moving_mean
# :) assinging batch_normalization_54/moving_variance to sequential_2/residual_block_17/batch_normalization_35/moving_variance
# :) assinging conv2d_72/kernel to sequential_2/residual_block_17/conv2d_42/kernel
# :) assinging batch_normalization_55/gamma to sequential_2/residual_block_17/batch_normalization_36/gamma
# :) assinging batch_normalization_55/beta to sequential_2/residual_block_17/batch_normalization_36/beta
# :) assinging batch_normalization_55/moving_mean to sequential_2/residual_block_17/batch_normalization_36/moving_mean
# :) assinging batch_normalization_55/moving_variance to sequential_2/residual_block_17/batch_normalization_36/moving_variance
# :) assinging conv2d_73/kernel to sequential_2/residual_block_17/conv2d_43/kernel
# :) assinging batch_normalization_56/gamma to sequential_2/batch_normalization_37/gamma
# :) assinging batch_normalization_56/beta to sequential_2/batch_normalization_37/beta
# :) assinging batch_normalization_56/moving_mean to sequential_2/batch_normalization_37/moving_mean
# :) assinging batch_normalization_56/moving_variance to sequential_2/batch_normalization_37/moving_variance

# %%
#from numpy import expand_dims
# pasamos de los pixeles de las imagenes a las características
#x_train = [ResidualNetworkSinClasificador(expand_dims(x_train[i], 0)) for i in range(x_train.shape[0])]

# %%
#from tensorflow import convert_to_tensor
# pasamos de una lista de tensores a un tensor
#x_train = convert_to_tensor(x_train)

# %%
# ...No se ha entrenado la red sin hacer uso de la función fit, 
# entrenando el modelo con un bucle de entrenamiento desde cero...

# definimos las funciones de entrenamiento
# inspirándonos en el libro de François Chollet
from math import inf
from math import ceil as techo
import matplotlib.pyplot as plt
import numpy as np
from tensorflow import GradientTape 
from tensorflow.keras import losses
from tensorflow.keras import optimizers
from tensorflow import reduce_mean
from time import time as tiempo

######################################################
class GeneradorBatches:

    def __init__(self, imagenes, etiquetas, tamanoBatch = 128):
        assert len(imagenes) == len(etiquetas)
        self.indice = 0
        self.imagenes = imagenes
        self.etiquetas = etiquetas
        self.tamanoBatch = tamanoBatch
        self.numBatches = techo(len(imagenes)/tamanoBatch)

    def siguiente(self):
        imagenes = self.imagenes[self.indice : self.indice + self.tamanoBatch]
        etiquetas = self.etiquetas[self.indice : self.indice + self.tamanoBatch]
        self.indice += self.tamanoBatch
        return imagenes, etiquetas

######################################################
def pasada(modelo, batchImagenes, batchEtiquetas, learning_rate=1e-3):
    
    with GradientTape() as memoria:
        predicciones = modelo(batchImagenes)
        perdidasInstancia = losses.categorical_crossentropy(batchEtiquetas, predicciones)
        perdidaMedia = reduce_mean(perdidasInstancia)
    gradientes = memoria.gradient(perdidaMedia, modelo.trainable_weights)
    optimizador = optimizers.Adam(learning_rate = learning_rate)
    optimizador.apply_gradients(zip(gradientes, modelo.trainable_weights))
    
    return perdidaMedia

######################################################
def entrena(modelo, imagenes, etiquetas, epochs, tamanoBatch, paradaTemprana='perdida', paciencilla = 15, learning_rate=1e-3):
    #diccionario para almacenar cada loss y acc de cada epoch
    hist = {
        "perdida_epoch" : [],
        "precision_epoch" : [],
        "perdida_batch" : [],
        "precision_batch" : []
    }
    
    stop = 0
    mejor_precision = 0.0
    mejor_loss = inf
    
    for epoch in range(epochs):   
        
        if stop > paciencilla :
            return hist
        
        antesEpoch = tiempo()
        print(f'Epoch: {epoch}')
        generadorBatches = GeneradorBatches(imagenes, etiquetas, tamanoBatch=tamanoBatch)
        
        for batch in range(generadorBatches.numBatches):
            
            antesBatch = tiempo()
            batchImagenes, batchEtiquetas = generadorBatches.siguiente()
            
            perdida = pasada(modelo, batchImagenes, batchEtiquetas, learning_rate=learning_rate)
            precision = compruebaConTest(modelo, 512)
            
            hist["perdida_batch" ].append(perdida.numpy())
            hist["precision_batch" ].append(precision)
            print(f'    Perdida en el batch {batch} = {perdida}')
            
            despuesBatch = tiempo()
            print(f'    Batch #{batch}/{generadorBatches.numBatches}, tardo {despuesBatch - antesBatch} segundos\n')
            
        hist["perdida_epoch"].append(hist["perdida_batch"][-1])
        hist["precision_epoch"].append(hist["precision_batch"][-1])
        
        if paradaTemprana == "precision":
            if mejor_precision < hist["precision_epoch"][-1] : 
                mejor_precision = hist["precision_epoch"][-1]
                stop = 0
            else: stop += 1 
        elif paradaTemprana == "perdida":
            if mejor_perdida > hist["perdida_epoch"][-1] : 
                mejor_precision = hist["perdida_epoch"][-1]
                stop = 0
            else: stop += 1
        despuesEpoch = tiempo()
        print(f'    Epoch #{epoch}, tardo {despuesEpoch - antesEpoch} segundos\n')
    return hist 

######################################################
def graficar(hist, batches =  True):
    if batches == True:
        fig, axes = plt.subplots(4,1, figsize = (20,20))
    else:
        fig, axes = plt.subplots(2,1, figsize = (20,20))
        
    epochs = len(hist["precision_epoch"])
    x = np.arange(1,epochs,1)
    axes[0].plot(x,hist["precision_epoch"])
    axes[0].set_title("Precisión x epochs")
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Precisión')
    axes[0].legend()

    axes[1].plot(x,hist["perdida_epoch"])
    axes[1].set_title("Perdida x epochs")
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Perdida')
    axes[1].legend()
    
    if batches == True:
        
        batches = len(hist["perdida_batch"])
        x = np.arange(1,batches,1)
        
        axes[2].plot(x,hist["precision_batch"])
        axes[2].set_title("Precisión x batches")
        axes[2].set_xlabel('Batches')
        axes[2].set_ylabel('Precisión')
        axes[2].legend()
        
        axes[3].plot(x,hist["perdida_batch"])
        axes[3].set_title("Perdida x batches")
        axes[3].set_xlabel('Batches')
        axes[3].set_ylabel('Perdida')
        axes[3].legend()
    plt.show()

# %%
'''
clasificador = Sequential( # definimos el clasificador
    [
        Input(shape=(256,)),
        Dropout(rate = .05),
        Dense(20, activation = 'relu'),
        Dropout(rate = .05),
        Dense(10, activation = 'softmax') # Dense con salida el número de clases del dataset
                                             # Softmax activation
    ]
)
''';

# %%
'''
from tensorflow.experimental.numpy import experimental_enable_numpy_behavior

experimental_enable_numpy_behavior()

x_train = x_train.reshape(50000,256)
''';

# %%
hist = entrena(modeloEjercicio3, x_train, y_train, epochs=2, tamanoBatch=2048,paradaTemprana = "precision", paciencilla=2, learning_rate=1e-3)
# Out:
# Epoch: 0
#     La tasa de acierto es 0.154296875
#     Perdida en el batch 0 = 2.5921428203582764
#     Batch #0/25, tardo 88.16404414176941 segundos
#
#     La tasa de acierto es 0.158203125
#     Perdida en el batch 1 = 2.5395426750183105
#     Batch #1/25, tardo 78.6652319431305 segundos
#
#     La tasa de acierto es 0.162109375
#     Perdida en el batch 2 = 2.4555680751800537
#     Batch #2/25, tardo 77.27769613265991 segundos
#
#     La tasa de acierto es 0.15625
#     Perdida en el batch 3 = 2.41371750831604
#     Batch #3/25, tardo 79.25289487838745 segundos
#
#     La tasa de acierto es 0.197265625
#     Perdida en el batch 4 = 2.349827766418457
#     Batch #4/25, tardo 74.78931093215942 segundos
#
#     La tasa de acierto es 0.19140625
#     Perdida en el batch 5 = 2.2832391262054443
#     Batch #5/25, tardo 110.04194188117981 segundos
#
#     La tasa de acierto es 0.1875
#     Perdida en el batch 6 = 2.2418742179870605
#     Batch #6/25, tardo 97.94061279296875 segundos
#
#     La tasa de acierto es 0.17578125
#     Perdida en el batch 7 = 2.205395221710205
#     Batch #7/25, tardo 81.21595978736877 segundos
#
#     La tasa de acierto es 0.208984375
#     Perdida en el batch 8 = 2.1414237022399902
#     Batch #8/25, tardo 78.55082106590271 segundos
#
#     La tasa de acierto es 0.23828125
#     Perdida en el batch 9 = 2.1035494804382324
#     Batch #9/25, tardo 82.55343627929688 segundos
#
#     La tasa de acierto es 0.279296875
#     Perdida en el batch 10 = 2.064892292022705
#     Batch #10/25, tardo 85.0547387599945 segundos
#
#     La tasa de acierto es 0.263671875
#     Perdida en el batch 11 = 2.027710437774658
#     Batch #11/25, tardo 80.34108209609985 segundos
#
#     La tasa de acierto es 0.314453125
#     Perdida en el batch 12 = 1.984248161315918
#     Batch #12/25, tardo 78.35231280326843 segundos
#
#     La tasa de acierto es 0.3125
#     Perdida en el batch 13 = 1.9497843980789185
#     Batch #13/25, tardo 80.73206877708435 segundos
#
#     La tasa de acierto es 0.35546875
#     Perdida en el batch 14 = 1.9080848693847656
#     Batch #14/25, tardo 95.38221883773804 segundos
#
#     La tasa de acierto es 0.341796875
#     Perdida en el batch 15 = 1.8946281671524048
#     Batch #15/25, tardo 85.33394503593445 segundos
#
#     La tasa de acierto es 0.3046875
#     Perdida en el batch 16 = 1.847503900527954
#     Batch #16/25, tardo 85.51806473731995 segundos
#
#     La tasa de acierto es 0.36328125
#     Perdida en el batch 17 = 1.842637062072754
#     Batch #17/25, tardo 83.31592202186584 segundos
#
#     La tasa de acierto es 0.390625
#     Perdida en el batch 18 = 1.8069190979003906
#     Batch #18/25, tardo 81.7386109828949 segundos
#
#     La tasa de acierto es 0.408203125
#     Perdida en el batch 19 = 1.7522315979003906
#     Batch #19/25, tardo 79.45899486541748 segundos
#
#     La tasa de acierto es 0.36328125
#     Perdida en el batch 20 = 1.7275595664978027
#     Batch #20/25, tardo 80.50366497039795 segundos
#
#     La tasa de acierto es 0.4453125
#     Perdida en el batch 21 = 1.693524718284607
#     Batch #21/25, tardo 87.05004692077637 segundos
#
#     La tasa de acierto es 0.416015625
#     Perdida en el batch 22 = 1.6685515642166138
#     Batch #22/25, tardo 110.70913004875183 segundos
#
#     La tasa de acierto es 0.431640625
#     Perdida en el batch 23 = 1.6332907676696777
#     Batch #23/25, tardo 118.15942907333374 segundos
#
#     La tasa de acierto es 0.40625
#     Perdida en el batch 24 = 1.5573842525482178
#     Batch #24/25, tardo 33.85103487968445 segundos
#
#     Epoch #0, tardo 2113.955123901367 segundos
#
# Epoch: 1
#     La tasa de acierto es 0.46484375
#     Perdida en el batch 0 = 1.5843679904937744
#     Batch #0/25, tardo 102.06121587753296 segundos
#
#     La tasa de acierto es 0.447265625
#     Perdida en el batch 1 = 1.5616503953933716
#     Batch #1/25, tardo 93.5690770149231 segundos
#
#     La tasa de acierto es 0.484375
#     Perdida en el batch 2 = 1.5260096788406372
#     Batch #2/25, tardo 94.64250206947327 segundos
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/v6/ybkmv61n1fgd69w84cn8vtqc0000gn/T/ipykernel_36396/3998263361.py in ?()
# ----> 1 hist = entrena(modeloEjercicio3, x_train, y_train, epochs=2, tamanoBatch=2048,paradaTemprana = "precision", paciencilla=2, learning_rate=1e-3)
#
# /var/folders/v6/ybkmv61n1fgd69w84cn8vtqc0000gn/T/ipykernel_36396/721647861.py in ?(modelo, imagenes, etiquetas, epochs, tamanoBatch, paradaTemprana, paciencilla, learning_rate)
#      70
#      71             antesBatch = tiempo()
#      72             batchImagenes, batchEtiquetas = generadorBatches.siguiente()
#      73
# ---> 74             perdida = pasada(modelo, batchImagenes, batchEtiquetas, learning_rate=learning_rate)
#      75             precision = compruebaConTest(modelo, 512)
#      76
#      77             hist["perdida_batch" ].append(perdida.numpy())
#
# /var/folders/v6/ybkmv61n1fgd69w84cn8vtqc0000gn/T/ipykernel_36396/721647861.py in ?(modelo, batchImagenes, batchEtiquetas, learning_rate)
#      36     with GradientTape() as memoria:
#      37         predicciones = modelo(batchImagenes)
#      38         perdidasInstancia = losses.categorical_crossentropy(batchEtiquetas, predicciones)
#      39         perdidaMedia = reduce_mean(perdidasInstancia)
# ---> 40     gradientes = memoria.gradient(perdidaMedia, modelo.trainable_weights)
#      41     optimizador = optimizers.Adam(learning_rate = learning_rate)
#      42     optimizador.apply_gradients(zip(gradientes, modelo.trainable_weights))
#      43
#
# ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/tensorflow/python/eager/backprop.py in ?(self, target, sources, output_gradients, unconnected_gradients)
#    1062               output_gradients))
#    1063       output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1064                           for x in output_gradients]
#    1065
# -> 1066     flat_grad = imperative_grad.imperative_grad(
#    1067         self._tape,
#    1068         flat_targets,
#    1069         flat_sources,
#
# ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/tensorflow/python/eager/imperative_grad.py in ?(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63   except ValueError:
#      64     raise ValueError(
#      65         "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
#      66
# ---> 67   return pywrap_tfe.TFE_Py_TapeGradient(
#      68       tape._tape,  # pylint: disable=protected-access
#      69       target,
#      70       sources,
#
# ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/tensorflow/python/ops/custom_gradient.py in ?(*result_grad_components)
#     579       if len(variable_grads) != len(variables):
#     580         raise ValueError("Must return gradient for each variable from "
#     581                          "@custom_gradient grad_fn.")
#     582     else:
# --> 583       input_grads = grad_fn(*result_grads)
#     584       variable_grads = []
#     585     flat_grads = composite_tensor_gradient.get_flat_tensors_for_gradients(
#     586         nest.flatten(input_grads))
#
# ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/tensorflow/python/ops/nn_impl.py in ?(dy)
#     470       with ops.control_dependencies([dy]):
#     471         sigmoid_features = math_ops.sigmoid(beta * features)
#     472
#     473       activation_grad = (
# --> 474           sigmoid_features * (1.0 + (beta * features) *
#     475                               (1.0 - sigmoid_features)))
#     476       beta_grad = math_ops.reduce_sum(
#     477           dy * math_ops.square(features) * sigmoid_features *
#
# ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/tensorflow/python/framework/override_binary_operator.py in ?(x, y)
#     110         # TODO(b/178860388): Figure out why binary_op_wrapper and
#     111         #   r_binary_op_wrapper use different force_same_dtype values.
#     112         x, y = maybe_promote_tensors(x, y)
#     113         return func(x, y, name=name)
# --> 114       except (TypeError, ValueError) as e:
#     115         # Even if dispatching the op failed, the RHS may be a tensor aware
#     116         # object that can implement the operator with knowledge of itself
#     117         # and the tensor.
#
# ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/tensorflow/python/ops/tensor_math_operator_overrides.py in ?(x, y, name)
#      61 def _mul_dispatch_factory(x, y, name=None):
#      62   from tensorflow.python.ops import math_ops
#      63
# ---> 64   return math_ops._mul_dispatch(x, y, name=name)  # pylint: disable=protected-access
#
# ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/tensorflow/python/ops/math_ops.py in ?(x, y, name)
#    1707     new_vals = gen_sparse_ops.sparse_dense_cwise_mul(y.indices, y.values,
#    1708                                                      y.dense_shape, x, name)
#    1709     return sparse_tensor.SparseTensor(y.indices, new_vals, y.dense_shape)
#    1710   else:
# -> 1711     return multiply(x, y, name=name)
#
# ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/tensorflow/python/ops/weak_tensor_ops.py in ?(*args, **kwargs)
#     140   def wrapper(*args, **kwargs):
#     141     if not ops.is_auto_dtype_conversion_enabled():
# --> 142       return op(*args, **kwargs)
#     143     bound_arguments = signature.bind(*args, **kwargs)
#     144     bound_arguments.apply_defaults()
#     145     bound_kwargs = bound_arguments.arguments
#
# ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/tensorflow/python/ops/math_ops.py in ?(x, y, name)
#     522
#     523    * InvalidArgumentError: When `x` and `y` have incompatible shapes or types.
#     524   """
#     525
# --> 526   return gen_math_ops.mul(x, y, name)
#
# ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/tensorflow/python/ops/gen_math_ops.py in ?(x, y, name)
#    6825         _ctx, "Mul", name, x, y)
#    6826       return _result
#    6827     except _core._NotOkStatusException as e:
#    6828       _ops.raise_from_not_ok_status(e, name)
# -> 6829     except _core._FallbackException:
#    6830       pass
#    6831     try:
#    6832       return mul_eager_fallback(
#
# KeyboardInterrupt:

# %%
#[x_train[i].shape for i in range(x_train.shape[0])]

# %%
graficar(hist=hist)

# %% [markdown]
#  ### $\huge\text{Ejercicio } 4$
# ### (_4 puntos_) Entrena, mediante la técnica de fine-tuning, sobre el dataset CIFAR-10, sin mantener fijos los pesos de la red preentrenada proporcionada en el canal de Teams de la asignatura. Analiza el resultado en el conjunto de test. Se penalizarán los siguientes puntos:
#  - (_-4 puntos_) No se ha entrenado la red correctamente, y no se proporciona el resultado obtenido en
# el conjunto de test.
#  - (_-1 punto_) No se ha utilizado la red original completa, a excepción de la última capa.
#  - (_-1 punto_) No se han mantenido congeladas las capas de BatchNormalization.
#  - (_-1 punto_) No se ha hecho uso de un learning rate muy bajo, con el objetivo de no perder las capacidades de generalización de los pesos preentrenados
#  - (_-2 puntos_) No se ha entrenado la red sin hacer uso de la función fit, entrenando el modelo con un
# bucle de entrenamiento desde cero.

# %%
from tensorflow.keras.layers import BatchNormalization

def descongelarModelo(modelo):
    # Descongelamos las capas, dejando BatchNormalization sin entrenar
    for layer in modelo.layers:
        if not isinstance(layer, BatchNormalization): # Comprueba que la capa no sea de tipo BatchNormalization
            layer.trainable = True

# %%
descongelarModelo(modeloEjercicio3)
hist2 = entrena(modeloEjercicio3, x_train, y_train, epochs=2, tamanoBatch=128,paradaTemprana = "precision", paciencilla=1, learning_rate=5e-5)
# Out:
# Epoch: 0
#     La tasa de acierto es 0.392578125
#     Perdida en el batch 0 = 1.4696695804595947
#     Batch #0/391, tardo 6.009095907211304 segundos
#
#     La tasa de acierto es 0.455078125
#     Perdida en el batch 1 = 1.5754773616790771
#     Batch #1/391, tardo 5.9184160232543945 segundos
#
#     La tasa de acierto es 0.443359375
#     Perdida en el batch 2 = 1.4988006353378296
#     Batch #2/391, tardo 5.871199131011963 segundos
#
#     La tasa de acierto es 0.521484375
#     Perdida en el batch 3 = 1.6774628162384033
#     Batch #3/391, tardo 5.832061767578125 segundos
#
#     La tasa de acierto es 0.509765625
#     Perdida en el batch 4 = 1.3627209663391113
#     Batch #4/391, tardo 5.915496826171875 segundos
#
#     La tasa de acierto es 0.515625
#     Perdida en el batch 5 = 1.5889108180999756
#     Batch #5/391, tardo 6.25778603553772 segundos
#
#     La tasa de acierto es 0.51171875
#     Perdida en el batch 6 = 1.4474891424179077
#     Batch #6/391, tardo 6.236769914627075 segundos
#
#     La tasa de acierto es 0.53125
#     Perdida en el batch 7 = 1.3648587465286255
#     Batch #7/391, tardo 6.201227188110352 segundos
#
#     La tasa de acierto es 0.458984375
#     Perdida en el batch 8 = 1.328571081161499
#     Batch #8/391, tardo 6.501924991607666 segundos
#
#     La tasa de acierto es 0.537109375
#     Perdida en el batch 9 = 1.209345817565918
#     Batch #9/391, tardo 6.609482049942017 segundos
#
#     La tasa de acierto es 0.5234375
#     Perdida en el batch 10 = 1.3617188930511475
#     Batch #10/391, tardo 6.414552211761475 segundos
#
#     La tasa de acierto es 0.5625
#     Perdida en el batch 11 = 1.3880574703216553
#     Batch #11/391, tardo 6.461236953735352 segundos
#
#     La tasa de acierto es 0.501953125
#     Perdida en el batch 12 = 1.122813105583191
#     Batch #12/391, tardo 6.418565273284912 segundos
#
#     La tasa de acierto es 0.556640625
#     Perdida en el batch 13 = 1.287208080291748
#     Batch #13/391, tardo 6.379591941833496 segundos
#
#     La tasa de acierto es 0.611328125
#     Perdida en el batch 14 = 1.0759832859039307
#     Batch #14/391, tardo 6.427457094192505 segundos
#
#     La tasa de acierto es 0.568359375
#     Perdida en el batch 15 = 1.2347259521484375
#     Batch #15/391, tardo 6.264332056045532 segundos
#
#     La tasa de acierto es 0.576171875
#     Perdida en el batch 16 = 1.1950573921203613
#     Batch #16/391, tardo 6.2063963413238525 segundos
#
#     La tasa de acierto es 0.56640625
#     Perdida en el batch 17 = 1.1155847311019897
#     Batch #17/391, tardo 6.191879987716675 segundos
#
#     La tasa de acierto es 0.59765625
#     Perdida en el batch 18 = 1.0313794612884521
#     Batch #18/391, tardo 6.2906718254089355 segundos
#
#     La tasa de acierto es 0.548828125
#     Perdida en el batch 19 = 1.1911687850952148
#     Batch #19/391, tardo 6.167258024215698 segundos
#
#     La tasa de acierto es 0.603515625
#     Perdida en el batch 20 = 1.1108981370925903
#     Batch #20/391, tardo 6.212043046951294 segundos
#
#     La tasa de acierto es 0.650390625
#     Perdida en el batch 21 = 1.141970157623291
#     Batch #21/391, tardo 6.149884223937988 segundos
#
#     La tasa de acierto es 0.625
#     Perdida en el batch 22 = 1.121993899345398
#     Batch #22/391, tardo 6.238276243209839 segundos
#
#     La tasa de acierto es 0.603515625
#     Perdida en el batch 23 = 1.2832154035568237
#     Batch #23/391, tardo 6.117997646331787 segundos
#
#     La tasa de acierto es 0.599609375
#     Perdida en el batch 24 = 1.0506011247634888
#     Batch #24/391, tardo 6.208988904953003 segundos
#
#     La tasa de acierto es 0.611328125
#     Perdida en el batch 25 = 1.0837397575378418
#     Batch #25/391, tardo 6.386253833770752 segundos
#
#     La tasa de acierto es 0.615234375
#     Perdida en el batch 26 = 1.2047538757324219
#     Batch #26/391, tardo 6.222767114639282 segundos
#
#     La tasa de acierto es 0.666015625
#     Perdida en el batch 27 = 1.1655869483947754
#     Batch #27/391, tardo 6.145493030548096 segundos
#
#     La tasa de acierto es 0.615234375
#     Perdida en el batch 28 = 1.0152093172073364
#     Batch #28/391, tardo 6.048795938491821 segundos
#
#     La tasa de acierto es 0.65625
#     Perdida en el batch 29 = 1.021610140800476
#     Batch #29/391, tardo 6.108871936798096 segundos
#
#     La tasa de acierto es 0.646484375
#     Perdida en el batch 30 = 1.0679389238357544
#     Batch #30/391, tardo 6.127368927001953 segundos
#
#     La tasa de acierto es 0.64453125
#     Perdida en el batch 31 = 1.1786136627197266
#     Batch #31/391, tardo 6.154569149017334 segundos
#
#     La tasa de acierto es 0.662109375
#     Perdida en el batch 32 = 1.0107330083847046
#     Batch #32/391, tardo 6.120748996734619 segundos
#
#     La tasa de acierto es 0.6640625
#     Perdida en el batch 33 = 1.018499732017517
#     Batch #33/391, tardo 6.183916091918945 segundos
#
#     La tasa de acierto es 0.59375
#     Perdida en el batch 34 = 0.9518133997917175
#     Batch #34/391, tardo 6.013487100601196 segundos
#
#     La tasa de acierto es 0.66796875
#     Perdida en el batch 35 = 0.9815506339073181
#     Batch #35/391, tardo 6.459004163742065 segundos
#
#     La tasa de acierto es 0.61328125
#     Perdida en el batch 36 = 0.9426127672195435
#     Batch #36/391, tardo 6.094863176345825 segundos
#
#     La tasa de acierto es 0.6640625
#     Perdida en el batch 37 = 1.0698280334472656
#     Batch #37/391, tardo 6.103937864303589 segundos
#
#     La tasa de acierto es 0.64453125
#     Perdida en el batch 38 = 1.1513835191726685
#     Batch #38/391, tardo 6.19519305229187 segundos
#
#     La tasa de acierto es 0.65625
#     Perdida en el batch 39 = 1.037299633026123
#     Batch #39/391, tardo 6.17432713508606 segundos
#
#     La tasa de acierto es 0.69140625
#     Perdida en el batch 40 = 1.101749062538147
#     Batch #40/391, tardo 6.1249799728393555 segundos
#
#     La tasa de acierto es 0.666015625
#     Perdida en el batch 41 = 0.9201092720031738
#     Batch #41/391, tardo 6.201493978500366 segundos
#
#     La tasa de acierto es 0.6953125
#     Perdida en el batch 42 = 1.083481788635254
#     Batch #42/391, tardo 6.3729259967803955 segundos
#
#     La tasa de acierto es 0.63671875
#     Perdida en el batch 43 = 0.9597486257553101
#     Batch #43/391, tardo 6.396527051925659 segundos
#
#     La tasa de acierto es 0.6953125
#     Perdida en el batch 44 = 0.9661559462547302
#     Batch #44/391, tardo 6.2798988819122314 segundos
#
#     La tasa de acierto es 0.62890625
#     Perdida en el batch 45 = 0.980899453163147
#     Batch #45/391, tardo 6.549272060394287 segundos
#
#     La tasa de acierto es 0.654296875
#     Perdida en el batch 46 = 0.9513347148895264
#     Batch #46/391, tardo 6.594688177108765 segundos
#
#     La tasa de acierto es 0.638671875
#     Perdida en el batch 47 = 1.0523661375045776
#     Batch #47/391, tardo 6.524717092514038 segundos
#
#     La tasa de acierto es 0.67578125
#     Perdida en el batch 48 = 0.9001734256744385
#     Batch #48/391, tardo 6.030766010284424 segundos
#
#     La tasa de acierto es 0.607421875
#     Perdida en el batch 49 = 0.9258619546890259
#     Batch #49/391, tardo 6.131164073944092 segundos
#
#     La tasa de acierto es 0.6328125
#     Perdida en el batch 50 = 0.9569092988967896
#     Batch #50/391, tardo 6.025834083557129 segundos
#
#     La tasa de acierto es 0.6484375
#     Perdida en el batch 51 = 0.9135863780975342
#     Batch #51/391, tardo 6.146295070648193 segundos
#
#     La tasa de acierto es 0.681640625
#     Perdida en el batch 52 = 0.8619557619094849
#     Batch #52/391, tardo 6.170390844345093 segundos
#
#     La tasa de acierto es 0.712890625
#     Perdida en el batch 53 = 1.2261124849319458
#     Batch #53/391, tardo 6.135519981384277 segundos
#
#     La tasa de acierto es 0.65625
#     Perdida en el batch 54 = 0.6553434133529663
#     Batch #54/391, tardo 6.214032888412476 segundos
#
#     La tasa de acierto es 0.65234375
#     Perdida en el batch 55 = 1.0768754482269287
#     Batch #55/391, tardo 6.157160997390747 segundos
#
#     La tasa de acierto es 0.6328125
#     Perdida en el batch 56 = 0.9650918245315552
#     Batch #56/391, tardo 6.209992170333862 segundos
#
#     La tasa de acierto es 0.654296875
#     Perdida en el batch 57 = 1.104841709136963
#     Batch #57/391, tardo 6.066662073135376 segundos
#
#     La tasa de acierto es 0.61328125
#     Perdida en el batch 58 = 0.7971053719520569
#     Batch #58/391, tardo 6.233899116516113 segundos
#
#     La tasa de acierto es 0.669921875
#     Perdida en el batch 59 = 1.1225851774215698
#     Batch #59/391, tardo 6.1587629318237305 segundos
#
#     La tasa de acierto es 0.73828125
#     Perdida en el batch 60 = 0.8575978875160217
#     Batch #60/391, tardo 6.177961826324463 segundos
#
#     La tasa de acierto es 0.65625
#     Perdida en el batch 61 = 1.0810182094573975
#     Batch #61/391, tardo 6.704430103302002 segundos
#
#     La tasa de acierto es 0.658203125
#     Perdida en el batch 62 = 1.0164313316345215
#     Batch #62/391, tardo 6.360079050064087 segundos
#
#     La tasa de acierto es 0.669921875
#     Perdida en el batch 63 = 0.8900753259658813
#     Batch #63/391, tardo 6.2736217975616455 segundos
#
#     La tasa de acierto es 0.6796875
#     Perdida en el batch 64 = 0.8910719156265259
#     Batch #64/391, tardo 6.346525192260742 segundos
#
#     La tasa de acierto es 0.69921875
#     Perdida en el batch 65 = 0.6995967626571655
#     Batch #65/391, tardo 6.171488046646118 segundos
#
#     La tasa de acierto es 0.7109375
#     Perdida en el batch 66 = 0.7762559652328491
#     Batch #66/391, tardo 6.193635702133179 segundos
#
#     La tasa de acierto es 0.69140625
#     Perdida en el batch 67 = 0.7902740240097046
#     Batch #67/391, tardo 6.291640996932983 segundos
#
#     La tasa de acierto es 0.68359375
#     Perdida en el batch 68 = 0.9464036822319031
#     Batch #68/391, tardo 6.151217222213745 segundos
#
#     La tasa de acierto es 0.67578125
#     Perdida en el batch 69 = 0.8911491632461548
#     Batch #69/391, tardo 6.1703550815582275 segundos
#
#     La tasa de acierto es 0.70703125
#     Perdida en el batch 70 = 0.805946946144104
#     Batch #70/391, tardo 6.149007797241211 segundos
#
#     La tasa de acierto es 0.732421875
#     Perdida en el batch 71 = 0.8682063221931458
#     Batch #71/391, tardo 6.131427049636841 segundos
#
#     La tasa de acierto es 0.7109375
#     Perdida en el batch 72 = 0.8704043626785278
#     Batch #72/391, tardo 6.10383415222168 segundos
#
#     La tasa de acierto es 0.740234375
#     Perdida en el batch 73 = 0.8720670938491821
#     Batch #73/391, tardo 6.144484758377075 segundos
#
#     La tasa de acierto es 0.728515625
#     Perdida en el batch 74 = 0.6298270225524902
#     Batch #74/391, tardo 6.072289228439331 segundos
#
#     La tasa de acierto es 0.75390625
#     Perdida en el batch 75 = 0.856415867805481
#     Batch #75/391, tardo 6.136707067489624 segundos
#
#     La tasa de acierto es 0.673828125
#     Perdida en el batch 76 = 0.9532698392868042
#     Batch #76/391, tardo 6.255483865737915 segundos
#
#     La tasa de acierto es 0.677734375
#     Perdida en el batch 77 = 0.8106578588485718
#     Batch #77/391, tardo 6.131318092346191 segundos
#
#     La tasa de acierto es 0.7265625
#     Perdida en el batch 78 = 0.8085094094276428
#     Batch #78/391, tardo 6.242950916290283 segundos
#
#     La tasa de acierto es 0.7109375
#     Perdida en el batch 79 = 0.9872784614562988
#     Batch #79/391, tardo 6.155983924865723 segundos
#
#     La tasa de acierto es 0.70703125
#     Perdida en el batch 80 = 0.9364867806434631
#     Batch #80/391, tardo 6.108587026596069 segundos
#
#     La tasa de acierto es 0.7109375
#     Perdida en el batch 81 = 1.1383111476898193
#     Batch #81/391, tardo 6.062778949737549 segundos
#
#     La tasa de acierto es 0.68359375
#     Perdida en el batch 82 = 0.8970092535018921
#     Batch #82/391, tardo 6.014862775802612 segundos
#
#     La tasa de acierto es 0.70703125
#     Perdida en el batch 83 = 0.7885124683380127
#     Batch #83/391, tardo 6.039154052734375 segundos
#
#     La tasa de acierto es 0.732421875
#     Perdida en el batch 84 = 0.729395866394043
#     Batch #84/391, tardo 6.091517925262451 segundos
#
#     La tasa de acierto es 0.771484375
#     Perdida en el batch 85 = 0.8199112415313721
#     Batch #85/391, tardo 6.030580997467041 segundos
#
#     La tasa de acierto es 0.73046875
#     Perdida en el batch 86 = 0.7952706217765808
#     Batch #86/391, tardo 6.212341070175171 segundos
#
#     La tasa de acierto es 0.671875
#     Perdida en el batch 87 = 0.8698949813842773
#     Batch #87/391, tardo 6.114887714385986 segundos
#
#     La tasa de acierto es 0.75390625
#     Perdida en el batch 88 = 0.8718945980072021
#     Batch #88/391, tardo 6.21354079246521 segundos
#
#     La tasa de acierto es 0.71875
#     Perdida en el batch 89 = 0.7354089021682739
#     Batch #89/391, tardo 6.1333441734313965 segundos
#
#     La tasa de acierto es 0.7265625
#     Perdida en el batch 90 = 0.7576996088027954
#     Batch #90/391, tardo 5.975476980209351 segundos
#
#     La tasa de acierto es 0.673828125
#     Perdida en el batch 91 = 0.7914001941680908
#     Batch #91/391, tardo 6.097113132476807 segundos
#
#     La tasa de acierto es 0.6953125
#     Perdida en el batch 92 = 0.6842834949493408
#     Batch #92/391, tardo 6.124770879745483 segundos
#
#     La tasa de acierto es 0.705078125
#     Perdida en el batch 93 = 0.8106867671012878
#     Batch #93/391, tardo 6.125381231307983 segundos
#
#     La tasa de acierto es 0.73046875
#     Perdida en el batch 94 = 0.8014639019966125
#     Batch #94/391, tardo 6.132408857345581 segundos
#
#     La tasa de acierto es 0.7109375
#     Perdida en el batch 95 = 0.9005211591720581
#     Batch #95/391, tardo 6.194601058959961 segundos
#
#     La tasa de acierto es 0.728515625
#     Perdida en el batch 96 = 0.8308416604995728
#     Batch #96/391, tardo 6.166906118392944 segundos
#
#     La tasa de acierto es 0.728515625
#     Perdida en el batch 97 = 0.8832046985626221
#     Batch #97/391, tardo 6.373661041259766 segundos
#
#     La tasa de acierto es 0.767578125
#     Perdida en el batch 98 = 0.7460675835609436
#     Batch #98/391, tardo 6.216247797012329 segundos
#
#     La tasa de acierto es 0.67578125
#     Perdida en el batch 99 = 0.7145131230354309
#     Batch #99/391, tardo 6.180861234664917 segundos
#
#     La tasa de acierto es 0.736328125
#     Perdida en el batch 100 = 0.8606150150299072
#     Batch #100/391, tardo 6.223135948181152 segundos
#
#     La tasa de acierto es 0.708984375
#     Perdida en el batch 101 = 0.7828439474105835
#     Batch #101/391, tardo 6.169203042984009 segundos
#
#     La tasa de acierto es 0.751953125
#     Perdida en el batch 102 = 0.8691697716712952
#     Batch #102/391, tardo 6.117637872695923 segundos
#
#     La tasa de acierto es 0.66796875
#     Perdida en el batch 103 = 0.7866796255111694
#     Batch #103/391, tardo 5.954490661621094 segundos
#
#     La tasa de acierto es 0.732421875
#     Perdida en el batch 104 = 0.9353551864624023
#     Batch #104/391, tardo 6.0931878089904785 segundos
#
#     La tasa de acierto es 0.7578125
#     Perdida en el batch 105 = 0.7201833724975586
#     Batch #105/391, tardo 6.088326930999756 segundos
#
#     La tasa de acierto es 0.720703125
#     Perdida en el batch 106 = 0.6747103333473206
#     Batch #106/391, tardo 6.144715070724487 segundos
#
#     La tasa de acierto es 0.7265625
#     Perdida en el batch 107 = 1.0162092447280884
#     Batch #107/391, tardo 6.180979251861572 segundos
#
#     La tasa de acierto es 0.744140625
#     Perdida en el batch 108 = 0.8744426965713501
#     Batch #108/391, tardo 6.16768217086792 segundos
#
#     La tasa de acierto es 0.748046875
#     Perdida en el batch 109 = 0.7464689016342163
#     Batch #109/391, tardo 6.067056894302368 segundos
#
#     La tasa de acierto es 0.77734375
#     Perdida en el batch 110 = 0.9409037828445435
#     Batch #110/391, tardo 6.189467906951904 segundos
#
#     La tasa de acierto es 0.732421875
#     Perdida en el batch 111 = 0.6851844787597656
#     Batch #111/391, tardo 6.2153730392456055 segundos
#
#     La tasa de acierto es 0.759765625
#     Perdida en el batch 112 = 0.7955754995346069
#     Batch #112/391, tardo 6.213665008544922 segundos
#
#     La tasa de acierto es 0.716796875
#     Perdida en el batch 113 = 0.8046976327896118
#     Batch #113/391, tardo 6.1232380867004395 segundos
#
#     La tasa de acierto es 0.744140625
#     Perdida en el batch 114 = 0.9079842567443848
#     Batch #114/391, tardo 6.20543098449707 segundos
#
#     La tasa de acierto es 0.73046875
#     Perdida en el batch 115 = 0.6684533357620239
#     Batch #115/391, tardo 6.205394744873047 segundos
#
#     La tasa de acierto es 0.744140625
#     Perdida en el batch 116 = 0.8488706350326538
#     Batch #116/391, tardo 6.176911115646362 segundos
#
#     La tasa de acierto es 0.734375
#     Perdida en el batch 117 = 0.655727207660675
#     Batch #117/391, tardo 6.136641979217529 segundos
#
#     La tasa de acierto es 0.689453125
#     Perdida en el batch 118 = 0.9334495663642883
#     Batch #118/391, tardo 6.203804969787598 segundos
#
#     La tasa de acierto es 0.71484375
#     Perdida en el batch 119 = 0.7907941341400146
#     Batch #119/391, tardo 6.236389875411987 segundos
#
#     La tasa de acierto es 0.7734375
#     Perdida en el batch 120 = 0.7260031700134277
#     Batch #120/391, tardo 6.110871076583862 segundos
#
#     La tasa de acierto es 0.759765625
#     Perdida en el batch 121 = 0.6540031433105469
#     Batch #121/391, tardo 6.143949031829834 segundos
#
#     La tasa de acierto es 0.716796875
#     Perdida en el batch 122 = 0.9056618809700012
#     Batch #122/391, tardo 6.04958701133728 segundos
#
#     La tasa de acierto es 0.720703125
#     Perdida en el batch 123 = 0.7455678582191467
#     Batch #123/391, tardo 6.010647773742676 segundos
#
#     La tasa de acierto es 0.759765625
#     Perdida en el batch 124 = 0.724694013595581
#     Batch #124/391, tardo 6.12996506690979 segundos
#
#     La tasa de acierto es 0.7265625
#     Perdida en el batch 125 = 0.707091212272644
#     Batch #125/391, tardo 6.157133102416992 segundos
#
#     La tasa de acierto es 0.744140625
#     Perdida en el batch 126 = 0.7957690954208374
#     Batch #126/391, tardo 6.231745958328247 segundos
#
#     La tasa de acierto es 0.744140625
#     Perdida en el batch 127 = 0.7105226516723633
#     Batch #127/391, tardo 6.449044227600098 segundos
#
#     La tasa de acierto es 0.71875
#     Perdida en el batch 128 = 0.7228718996047974
#     Batch #128/391, tardo 6.314212799072266 segundos
#
#     La tasa de acierto es 0.75
#     Perdida en el batch 129 = 0.8370150327682495
#     Batch #129/391, tardo 6.252629041671753 segundos
#
#     La tasa de acierto es 0.73046875
#     Perdida en el batch 130 = 0.6458687782287598
#     Batch #130/391, tardo 6.162698030471802 segundos
#
#     La tasa de acierto es 0.7578125
#     Perdida en el batch 131 = 0.7764882445335388
#     Batch #131/391, tardo 6.164353132247925 segundos
#
#     La tasa de acierto es 0.740234375
#     Perdida en el batch 132 = 0.5490267276763916
#     Batch #132/391, tardo 6.260169982910156 segundos
#
#     La tasa de acierto es 0.7421875
#     Perdida en el batch 133 = 0.7247830629348755
#     Batch #133/391, tardo 6.132496118545532 segundos
#
#     La tasa de acierto es 0.724609375
#     Perdida en el batch 134 = 0.6850049495697021
#     Batch #134/391, tardo 6.085668087005615 segundos
#
#     La tasa de acierto es 0.76953125
#     Perdida en el batch 135 = 0.7943742871284485
#     Batch #135/391, tardo 6.171236753463745 segundos
#
#     La tasa de acierto es 0.71484375
#     Perdida en el batch 136 = 0.7278461456298828
#     Batch #136/391, tardo 6.134647846221924 segundos
#
#     La tasa de acierto es 0.75390625
#     Perdida en el batch 137 = 0.5384974479675293
#     Batch #137/391, tardo 6.178595066070557 segundos
#
#     La tasa de acierto es 0.69921875
#     Perdida en el batch 138 = 0.8568951487541199
#     Batch #138/391, tardo 6.15042519569397 segundos
#
#     La tasa de acierto es 0.771484375
#     Perdida en el batch 139 = 0.7056310176849365
#     Batch #139/391, tardo 6.143730163574219 segundos
#
#     La tasa de acierto es 0.7421875
#     Perdida en el batch 140 = 0.7879951000213623
#     Batch #140/391, tardo 6.2202839851379395 segundos
#
#     La tasa de acierto es 0.744140625
#     Perdida en el batch 141 = 0.7184902429580688
#     Batch #141/391, tardo 6.010978937149048 segundos
#
#     La tasa de acierto es 0.771484375
#     Perdida en el batch 142 = 0.7147663831710815
#     Batch #142/391, tardo 6.083209037780762 segundos
#
#     La tasa de acierto es 0.74609375
#     Perdida en el batch 143 = 0.5988371968269348
#     Batch #143/391, tardo 6.073280096054077 segundos
#
#     La tasa de acierto es 0.732421875
#     Perdida en el batch 144 = 0.921465277671814
#     Batch #144/391, tardo 6.158616065979004 segundos
#
#     La tasa de acierto es 0.7734375
#     Perdida en el batch 145 = 0.7442477941513062
#     Batch #145/391, tardo 6.204532861709595 segundos
#
#     La tasa de acierto es 0.736328125
#     Perdida en el batch 146 = 0.5832850933074951
#     Batch #146/391, tardo 6.1584861278533936 segundos
#
#     La tasa de acierto es 0.771484375
#     Perdida en el batch 147 = 0.6562328934669495
#     Batch #147/391, tardo 6.122418165206909 segundos
#
#     La tasa de acierto es 0.734375
#     Perdida en el batch 148 = 0.7460007071495056
#     Batch #148/391, tardo 6.1826300621032715 segundos
#
#     La tasa de acierto es 0.775390625
#     Perdida en el batch 149 = 0.6990559697151184
#     Batch #149/391, tardo 6.160992860794067 segundos
#
#     La tasa de acierto es 0.791015625
#     Perdida en el batch 150 = 0.6139649152755737
#     Batch #150/391, tardo 6.1528661251068115 segundos
#
#     La tasa de acierto es 0.7109375
#     Perdida en el batch 151 = 0.636265754699707
#     Batch #151/391, tardo 6.0653369426727295 segundos
#
#     La tasa de acierto es 0.767578125
#     Perdida en el batch 152 = 0.9202120304107666
#     Batch #152/391, tardo 6.147049903869629 segundos
#
#     La tasa de acierto es 0.7265625
#     Perdida en el batch 153 = 0.6288576126098633
#     Batch #153/391, tardo 6.260967254638672 segundos
#
#     La tasa de acierto es 0.7578125
#     Perdida en el batch 154 = 0.8320344090461731
#     Batch #154/391, tardo 6.199999094009399 segundos
#
#     La tasa de acierto es 0.71875
#     Perdida en el batch 155 = 0.6660043001174927
#     Batch #155/391, tardo 6.2734010219573975 segundos
#
#     La tasa de acierto es 0.763671875
#     Perdida en el batch 156 = 0.8180427551269531
#     Batch #156/391, tardo 6.177937984466553 segundos
#
#     La tasa de acierto es 0.755859375
#     Perdida en el batch 157 = 0.6708166003227234
#     Batch #157/391, tardo 7.555818796157837 segundos
#
#     La tasa de acierto es 0.748046875
#     Perdida en el batch 158 = 0.8863681554794312
#     Batch #158/391, tardo 6.286379814147949 segundos
#
#     La tasa de acierto es 0.748046875
#     Perdida en el batch 159 = 0.7436124682426453
#     Batch #159/391, tardo 6.235267877578735 segundos
#
#     La tasa de acierto es 0.77734375
#     Perdida en el batch 160 = 0.8205296397209167
#     Batch #160/391, tardo 6.205562114715576 segundos
#
#     La tasa de acierto es 0.75
#     Perdida en el batch 161 = 0.6826012134552002
#     Batch #161/391, tardo 6.213680267333984 segundos
#
#     La tasa de acierto es 0.76953125
#     Perdida en el batch 162 = 0.6743577718734741
#     Batch #162/391, tardo 6.206275939941406 segundos
#
#     La tasa de acierto es 0.75
#     Perdida en el batch 163 = 0.5338940620422363
#     Batch #163/391, tardo 6.124717950820923 segundos
#
#     La tasa de acierto es 0.755859375
#     Perdida en el batch 164 = 0.7675003409385681
#     Batch #164/391, tardo 6.164265871047974 segundos
#
#     La tasa de acierto es 0.765625
#     Perdida en el batch 165 = 0.6222717761993408
#     Batch #165/391, tardo 6.134923934936523 segundos
#
#     La tasa de acierto es 0.76171875
#     Perdida en el batch 166 = 0.7409231662750244
#     Batch #166/391, tardo 6.095444917678833 segundos
#
#     La tasa de acierto es 0.732421875
#     Perdida en el batch 167 = 0.7720795273780823
#     Batch #167/391, tardo 6.077606678009033 segundos
#
#     La tasa de acierto es 0.791015625
#     Perdida en el batch 168 = 0.7559916973114014
#     Batch #168/391, tardo 6.102053880691528 segundos
#
#     La tasa de acierto es 0.78515625
#     Perdida en el batch 169 = 0.8317878246307373
#     Batch #169/391, tardo 6.118790864944458 segundos
#
#     La tasa de acierto es 0.765625
#     Perdida en el batch 170 = 0.7935610413551331
#     Batch #170/391, tardo 6.083814859390259 segundos
#
#     La tasa de acierto es 0.783203125
#     Perdida en el batch 171 = 0.7047308683395386
#     Batch #171/391, tardo 6.05840277671814 segundos
#
#     La tasa de acierto es 0.7734375
#     Perdida en el batch 172 = 0.6744683980941772
#     Batch #172/391, tardo 6.081308841705322 segundos
#
#     La tasa de acierto es 0.78125
#     Perdida en el batch 173 = 0.6474220156669617
#     Batch #173/391, tardo 6.145051956176758 segundos
#
#     La tasa de acierto es 0.76953125
#     Perdida en el batch 174 = 0.6540186405181885
#     Batch #174/391, tardo 6.202570915222168 segundos
#
#     La tasa de acierto es 0.755859375
#     Perdida en el batch 175 = 0.8210861682891846
#     Batch #175/391, tardo 6.077606916427612 segundos
#
#     La tasa de acierto es 0.75390625
#     Perdida en el batch 176 = 0.6778347492218018
#     Batch #176/391, tardo 6.177597999572754 segundos
#
#     La tasa de acierto es 0.765625
#     Perdida en el batch 177 = 0.7983598709106445
#     Batch #177/391, tardo 6.25813102722168 segundos
#
#     La tasa de acierto es 0.775390625
#     Perdida en el batch 178 = 0.7213913202285767
#     Batch #178/391, tardo 6.166357040405273 segundos
#
#     La tasa de acierto es 0.7265625
#     Perdida en el batch 179 = 0.644370436668396
#     Batch #179/391, tardo 6.250112056732178 segundos
#
#     La tasa de acierto es 0.765625
#     Perdida en el batch 180 = 0.5876911282539368
#     Batch #180/391, tardo 6.137599945068359 segundos
#
#     La tasa de acierto es 0.775390625
#     Perdida en el batch 181 = 0.6075416803359985
#     Batch #181/391, tardo 6.457849025726318 segundos
#
#     La tasa de acierto es 0.77734375
#     Perdida en el batch 182 = 0.7247596979141235
#     Batch #182/391, tardo 6.2125959396362305 segundos
#
#     La tasa de acierto es 0.75
#     Perdida en el batch 183 = 0.6949855089187622
#     Batch #183/391, tardo 6.402189016342163 segundos
#
#     La tasa de acierto es 0.744140625
#     Perdida en el batch 184 = 0.7391140460968018
#     Batch #184/391, tardo 6.384577035903931 segundos
#
#     La tasa de acierto es 0.7734375
#     Perdida en el batch 185 = 0.6687204241752625
#     Batch #185/391, tardo 6.241894960403442 segundos
#
#     La tasa de acierto es 0.796875
#     Perdida en el batch 186 = 0.6009299755096436
#     Batch #186/391, tardo 6.657745838165283 segundos
#
#     La tasa de acierto es 0.73046875
#     Perdida en el batch 187 = 0.5642071962356567
#     Batch #187/391, tardo 6.17838978767395 segundos
#
#     La tasa de acierto es 0.80078125
#     Perdida en el batch 188 = 0.731247067451477
#     Batch #188/391, tardo 6.068233013153076 segundos
#
#     La tasa de acierto es 0.794921875
#     Perdida en el batch 189 = 0.699725329875946
#     Batch #189/391, tardo 6.202359199523926 segundos
#
#     La tasa de acierto es 0.7421875
#     Perdida en el batch 190 = 0.6867966651916504
#     Batch #190/391, tardo 6.532344818115234 segundos
#
#     La tasa de acierto es 0.80859375
#     Perdida en el batch 191 = 0.577885091304779
#     Batch #191/391, tardo 6.36773419380188 segundos
#
#     La tasa de acierto es 0.779296875
#     Perdida en el batch 192 = 0.5457673072814941
#     Batch #192/391, tardo 6.176165819168091 segundos
#
#     La tasa de acierto es 0.7421875
#     Perdida en el batch 193 = 0.8101310133934021
#     Batch #193/391, tardo 6.254091024398804 segundos
#
#     La tasa de acierto es 0.775390625
#     Perdida en el batch 194 = 0.5606487989425659
#     Batch #194/391, tardo 6.1795759201049805 segundos
#
#     La tasa de acierto es 0.775390625
#     Perdida en el batch 195 = 0.43137073516845703
#     Batch #195/391, tardo 6.029799222946167 segundos
#
#     La tasa de acierto es 0.76171875
#     Perdida en el batch 196 = 0.8166797161102295
#     Batch #196/391, tardo 6.121715068817139 segundos
#
#     La tasa de acierto es 0.77734375
#     Perdida en el batch 197 = 0.7661284804344177
#     Batch #197/391, tardo 6.101819038391113 segundos
#
#     La tasa de acierto es 0.76953125
#     Perdida en el batch 198 = 0.6634146571159363
#     Batch #198/391, tardo 6.166292190551758 segundos
#
#     La tasa de acierto es 0.78515625
#     Perdida en el batch 199 = 0.6477680206298828
#     Batch #199/391, tardo 6.120357990264893 segundos
#
#     La tasa de acierto es 0.76171875
#     Perdida en el batch 200 = 0.6703305244445801
#     Batch #200/391, tardo 6.126596927642822 segundos
#
#     La tasa de acierto es 0.78515625
#     Perdida en el batch 201 = 0.574968159198761
#     Batch #201/391, tardo 6.159248113632202 segundos
#
#     La tasa de acierto es 0.765625
#     Perdida en el batch 202 = 0.5496076345443726
#     Batch #202/391, tardo 6.087525129318237 segundos
#
#     La tasa de acierto es 0.751953125
#     Perdida en el batch 203 = 0.5290971994400024
#     Batch #203/391, tardo 6.102854013442993 segundos
#
#     La tasa de acierto es 0.798828125
#     Perdida en el batch 204 = 0.5959854125976562
#     Batch #204/391, tardo 6.090476751327515 segundos
#
#     La tasa de acierto es 0.76953125
#     Perdida en el batch 205 = 0.7191855311393738
#     Batch #205/391, tardo 6.040217876434326 segundos
#
#     La tasa de acierto es 0.78125
#     Perdida en el batch 206 = 0.6848805546760559
#     Batch #206/391, tardo 6.108088254928589 segundos
#
#     La tasa de acierto es 0.7734375
#     Perdida en el batch 207 = 0.6109560132026672
#     Batch #207/391, tardo 6.130347013473511 segundos
#
#     La tasa de acierto es 0.765625
#     Perdida en el batch 208 = 0.6741187572479248
#     Batch #208/391, tardo 6.1113080978393555 segundos
#
#     La tasa de acierto es 0.763671875
#     Perdida en el batch 209 = 0.6804366111755371
#     Batch #209/391, tardo 6.067511796951294 segundos
#
#     La tasa de acierto es 0.763671875
#     Perdida en el batch 210 = 0.6348901391029358
#     Batch #210/391, tardo 6.080911159515381 segundos
#
#     La tasa de acierto es 0.80859375
#     Perdida en el batch 211 = 0.8517254590988159
#     Batch #211/391, tardo 6.119702100753784 segundos
#
#     La tasa de acierto es 0.728515625
#     Perdida en el batch 212 = 0.6360923051834106
#     Batch #212/391, tardo 6.121005058288574 segundos
#
#     La tasa de acierto es 0.7734375
#     Perdida en el batch 213 = 0.5573461651802063
#     Batch #213/391, tardo 6.121362924575806 segundos
#
#     La tasa de acierto es 0.79296875
#     Perdida en el batch 214 = 0.6178924441337585
#     Batch #214/391, tardo 6.274585008621216 segundos
#
#     La tasa de acierto es 0.775390625
#     Perdida en el batch 215 = 0.71067875623703
#     Batch #215/391, tardo 6.264510869979858 segundos
#
#     La tasa de acierto es 0.8125
#     Perdida en el batch 216 = 0.6437137126922607
#     Batch #216/391, tardo 6.4274351596832275 segundos
#
#     La tasa de acierto es 0.728515625
#     Perdida en el batch 217 = 0.5036645531654358
#     Batch #217/391, tardo 6.342988014221191 segundos
#
#     La tasa de acierto es 0.775390625
#     Perdida en el batch 218 = 0.7109805345535278
#     Batch #218/391, tardo 6.327938079833984 segundos
#
#     La tasa de acierto es 0.7578125
#     Perdida en el batch 219 = 0.5303756594657898
#     Batch #219/391, tardo 6.185617923736572 segundos
#
#     La tasa de acierto es 0.77734375
#     Perdida en el batch 220 = 0.5573986172676086
#     Batch #220/391, tardo 6.262859106063843 segundos
#
#     La tasa de acierto es 0.763671875
#     Perdida en el batch 221 = 0.6539195775985718
#     Batch #221/391, tardo 6.48576283454895 segundos
#
#     La tasa de acierto es 0.798828125
#     Perdida en el batch 222 = 0.6118553876876831
#     Batch #222/391, tardo 6.43137526512146 segundos
#
#     La tasa de acierto es 0.771484375
#     Perdida en el batch 223 = 0.7973342537879944
#     Batch #223/391, tardo 6.563812017440796 segundos
#
#     La tasa de acierto es 0.78515625
#     Perdida en el batch 224 = 0.6878335475921631
#     Batch #224/391, tardo 6.584561824798584 segundos
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 descongelarModelo(modeloEjercicio3)
# ----> 2 hist2 = entrena(modeloEjercicio3, x_train, y_train, epochs=2, tamanoBatch=128,paradaTemprana = "precision", paciencilla=1, learning_rate=5e-5)
#
# Cell In[12], line 75, in entrena(modelo, imagenes, etiquetas, epochs, tamanoBatch, paradaTemprana, paciencilla, learning_rate)
#      72 batchImagenes, batchEtiquetas = generadorBatches.siguiente()
#      74 perdida = pasada(modelo, batchImagenes, batchEtiquetas, learning_rate=learning_rate)
# ---> 75 precision = compruebaConTest(modelo, 512)
#      77 hist["perdida_batch" ].append(perdida.numpy())
#      78 hist["precision_batch" ].append(precision)
#
# Cell In[6], line 6, in compruebaConTest(modelo, numeroEjemplos)
#       4 def compruebaConTest(modelo, numeroEjemplos):
#       5     indices = [randint(0,x_test.shape[0]-1) for _ in range(numeroEjemplos)]
# ----> 6     y_pred = modelo(x_test[indices])
#       7     tasaAcierto = sum([np.argmax(y_pred[i]) == np.argmax(y_test[indice]) for i, indice in enumerate(indices)])/numeroEjemplos
#       8     print(f'    La tasa de acierto es {tasaAcierto}')
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/layers/layer.py:901, in Layer.__call__(self, *args, **kwargs)
#     899         outputs = super().__call__(*args, **kwargs)
#     900 else:
# --> 901     outputs = super().__call__(*args, **kwargs)
#     902 # Change the layout for the layer output if needed.
#     903 # This is useful for relayout intermediate tensor in the model
#     904 # to achieve the optimal performance.
#     905 distribution = distribution_lib.distribution()
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/models/functional.py:175, in Functional.call(self, inputs, training, mask)
#     173         if mask is not None:
#     174             x._keras_mask = mask
# --> 175 outputs = self._run_through_graph(
#     176     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     177 )
#     178 return unpack_singleton(outputs)
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/ops/function.py:171, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     169     outputs = call_fn(op, *args, **kwargs)
#     170 else:
# --> 171     outputs = op(*args, **kwargs)
#     173 # Update tensor_dict.
#     174 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/models/functional.py:560, in operation_fn.<locals>.call(*args, **kwargs)
#     554 if (
#     555     hasattr(operation, "_call_has_training_arg")
#     556     and operation._call_has_training_arg
#     557     and training is not None
#     558 ):
#     559     kwargs["training"] = training
# --> 560 return operation(*args, **kwargs)
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/layers/layer.py:901, in Layer.__call__(self, *args, **kwargs)
#     899         outputs = super().__call__(*args, **kwargs)
#     900 else:
# --> 901     outputs = super().__call__(*args, **kwargs)
#     902 # Change the layout for the layer output if needed.
#     903 # This is useful for relayout intermediate tensor in the model
#     904 # to achieve the optimal performance.
#     905 distribution = distribution_lib.distribution()
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/models/sequential.py:212, in Sequential.call(self, inputs, training, mask)
#     210 def call(self, inputs, training=None, mask=None):
#     211     if self._functional:
# --> 212         return self._functional.call(inputs, training=training, mask=mask)
#     214     # Fallback: Just apply the layer sequence.
#     215     # This typically happens if `inputs` is a nested struct.
#     216     for layer in self.layers:
#     217         # During each iteration, `inputs` are the inputs to `layer`, and
#     218         # `outputs` are the outputs of `layer` applied to `inputs`. At the
#     219         # end of each iteration `inputs` is set to `outputs` to prepare for
#     220         # the next layer.
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/models/functional.py:175, in Functional.call(self, inputs, training, mask)
#     173         if mask is not None:
#     174             x._keras_mask = mask
# --> 175 outputs = self._run_through_graph(
#     176     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     177 )
#     178 return unpack_singleton(outputs)
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/ops/function.py:171, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     169     outputs = call_fn(op, *args, **kwargs)
#     170 else:
# --> 171     outputs = op(*args, **kwargs)
#     173 # Update tensor_dict.
#     174 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/models/functional.py:560, in operation_fn.<locals>.call(*args, **kwargs)
#     554 if (
#     555     hasattr(operation, "_call_has_training_arg")
#     556     and operation._call_has_training_arg
#     557     and training is not None
#     558 ):
#     559     kwargs["training"] = training
# --> 560 return operation(*args, **kwargs)
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/layers/layer.py:901, in Layer.__call__(self, *args, **kwargs)
#     899         outputs = super().__call__(*args, **kwargs)
#     900 else:
# --> 901     outputs = super().__call__(*args, **kwargs)
#     902 # Change the layout for the layer output if needed.
#     903 # This is useful for relayout intermediate tensor in the model
#     904 # to achieve the optimal performance.
#     905 distribution = distribution_lib.distribution()
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# Cell In[1], line 35, in ResidualBlock.call(self, x)
#      33 x = self.BN1(x)
#      34 y = activations.silu(x)
# ---> 35 x = self.Conv1(y)
#      36 x = self.BN2(x)
#      37 x = activations.silu(x)
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/layers/layer.py:901, in Layer.__call__(self, *args, **kwargs)
#     899         outputs = super().__call__(*args, **kwargs)
#     900 else:
# --> 901     outputs = super().__call__(*args, **kwargs)
#     902 # Change the layout for the layer output if needed.
#     903 # This is useful for relayout intermediate tensor in the model
#     904 # to achieve the optimal performance.
#     905 distribution = distribution_lib.distribution()
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:243, in BaseConv.call(self, inputs)
#     242 def call(self, inputs):
# --> 243     outputs = self.convolution_op(
#     244         inputs,
#     245         self.kernel,
#     246     )
#     247     if self.use_bias:
#     248         if self.data_format == "channels_last":
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:233, in BaseConv.convolution_op(self, inputs, kernel)
#     232 def convolution_op(self, inputs, kernel):
# --> 233     return ops.conv(
#     234         inputs,
#     235         kernel,
#     236         strides=list(self.strides),
#     237         padding=self.padding,
#     238         dilation_rate=self.dilation_rate,
#     239         data_format=self.data_format,
#     240     )
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/ops/nn.py:901, in conv(inputs, kernel, strides, padding, data_format, dilation_rate)
#     897 if any_symbolic_tensors((inputs,)):
#     898     return Conv(strides, padding, data_format, dilation_rate).symbolic_call(
#     899         inputs, kernel
#     900     )
# --> 901 return backend.nn.conv(
#     902     inputs, kernel, strides, padding, data_format, dilation_rate
#     903 )
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/backend/tensorflow/nn.py:258, in conv(inputs, kernel, strides, padding, data_format, dilation_rate)
#     256     return _conv_xla()
#     257 else:
# --> 258     return _conv()
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/keras/src/backend/tensorflow/nn.py:231, in conv.<locals>._conv()
#     229 def _conv():
#     230     tf_data_format = _convert_data_format(data_format, len(inputs.shape))
# --> 231     return tf.nn.convolution(
#     232         inputs,
#     233         kernel,
#     234         strides,
#     235         padding.upper(),
#     236         data_format=tf_data_format,
#     237         dilations=dilation_rate,
#     238     )
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/tensorflow/python/ops/nn_ops.py:1186, in convolution_v2(input, filters, strides, padding, data_format, dilations, name)
#    1176 @tf_export("nn.convolution", v1=[])
#    1177 @dispatch.add_dispatch_support
#    1178 def convolution_v2(  # pylint: disable=missing-docstring
#    (...)
#    1184     dilations=None,
#    1185     name=None):
# -> 1186   return convolution_internal(
#    1187       input,  # pylint: disable=redefined-builtin
#    1188       filters,
#    1189       strides=strides,
#    1190       padding=padding,
#    1191       data_format=data_format,
#    1192       dilations=dilations,
#    1193       name=name)
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/tensorflow/python/ops/nn_ops.py:1319, in convolution_internal(input, filters, strides, padding, data_format, dilations, name, call_from_convolution, num_spatial_dims)
#    1316   else:
#    1317     op = conv1d
# -> 1319   return op(
#    1320       input,
#    1321       filters,
#    1322       strides,
#    1323       padding=padding,
#    1324       data_format=data_format,
#    1325       dilations=dilations,
#    1326       name=name)
#    1327 else:
#    1328   if channel_index == 1:
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/tensorflow/python/ops/nn_ops.py:2793, in _conv2d_expanded_batch(input, filters, strides, padding, data_format, dilations, name)
#    2789 input_rank = input.shape.rank
#    2790 if input_rank is None or input_rank < 5:
#    2791   # We avoid calling squeeze_batch_dims to reduce extra python function
#    2792   # call slowdown in eager mode.  This branch doesn't require reshapes.
# -> 2793   return gen_nn_ops.conv2d(
#    2794       input,
#    2795       filter=filters,
#    2796       strides=strides,
#    2797       padding=padding,
#    2798       data_format=data_format,
#    2799       dilations=dilations,
#    2800       name=name)
#    2801 return squeeze_batch_dims(
#    2802     input,
#    2803     functools.partial(
#    (...)
#    2810     inner_rank=3,
#    2811     name=name)
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/tensorflow/python/ops/gen_nn_ops.py:1345, in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#    1343   pass
#    1344 try:
# -> 1345   return conv2d_eager_fallback(
#    1346       input, filter, strides=strides, use_cudnn_on_gpu=use_cudnn_on_gpu,
#    1347       padding=padding, explicit_paddings=explicit_paddings,
#    1348       data_format=data_format, dilations=dilations, name=name, ctx=_ctx)
#    1349 except _core._SymbolicException:
#    1350   pass  # Add nodes to the TensorFlow graph.
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/tensorflow/python/ops/gen_nn_ops.py:1434, in conv2d_eager_fallback(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name, ctx)
#    1430 _inputs_flat = [input, filter]
#    1431 _attrs = ("T", _attr_T, "strides", strides, "use_cudnn_on_gpu",
#    1432 use_cudnn_on_gpu, "padding", padding, "explicit_paddings",
#    1433 explicit_paddings, "data_format", data_format, "dilations", dilations)
# -> 1434 _result = _execute.execute(b"Conv2D", 1, inputs=_inputs_flat, attrs=_attrs,
#    1435                            ctx=ctx, name=name)
#    1436 if _execute.must_record_gradient():
#    1437   _execute.record_gradient(
#    1438       "Conv2D", _inputs_flat, _attrs, _result)
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedaCoruña/carrera/3/1/ap/Ent_AP/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
graficar(hist=hist2)
